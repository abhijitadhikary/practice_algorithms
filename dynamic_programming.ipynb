# %%
import numpy as np

# %% [markdown]
# ### 1. 1st `n` Fibonacchi numbers

# %%
def fibonacchi_dyn(n, memo={}):
    assert n >= 0, 'Please enter a positive number for the n-th fibonacchi number'
    if n in memo:
        return memo[n]
    elif n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        memo[n-1] = fibonacchi_dyn(n-1, memo)
        memo[n-2] = fibonacchi_dyn(n-2, memo)
        return memo[n-1] + memo[n-2]
        
for index in range(1, 100+1):
    print(index, fibonacchi_dyn(index), end='\n')
# Out:
# 1 0
# 2 1
# 3 1
# 4 2
# 5 3
# 6 5
# 7 8
# 8 13
# 9 21
# 10 34
# 11 55
# 12 89
# 13 144
# 14 233
# 15 377
# 16 610
# 17 987
# 18 1597
# 19 2584
# 20 4181
# 21 6765
# 22 10946
# 23 17711
# 24 28657
# 25 46368
# 26 75025
# 27 121393
# 28 196418
# 29 317811
# 30 514229
# 31 832040
# 32 1346269
# 33 2178309
# 34 3524578
# 35 5702887
# 36 9227465
# 37 14930352
# 38 24157817
# 39 39088169
# 40 63245986
# 41 102334155
# 42 165580141
# 43 267914296
# 44 433494437
# 45 701408733
# 46 1134903170
# 47 1836311903
# 48 2971215073
# 49 4807526976
# 50 7778742049
# 51 12586269025
# 52 20365011074
# 53 32951280099
# 54 53316291173
# 55 86267571272
# 56 139583862445
# 57 225851433717
# 58 365435296162
# 59 591286729879
# 60 956722026041
# 61 1548008755920
# 62 2504730781961
# 63 4052739537881
# 64 6557470319842
# 65 10610209857723
# 66 17167680177565
# 67 27777890035288
# 68 44945570212853
# 69 72723460248141
# 70 117669030460994
# 71 190392490709135
# 72 308061521170129
# 73 498454011879264
# ...
